# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
msg = "Explain the theory of relativity in simple terms."
response = llm.invoke(msg)
print(response)
# Out:
# content='Einstein\'s Theory of Relativity is a cornerstone of modern physics, and it fundamentally changed our understanding of space, time, gravity, and the universe. It\'s often broken into two parts: **Special Relativity** and **General Relativity**.\n\nThe core idea is that **space and time are not absolute and fixed, but are flexible and can be affected by motion and gravity.** Everything is relative, except for one very important thing: the speed of light.\n\nLet\'s break it down:\n\n---\n\n## Part 1: Special Relativity (1905)\n\nThis part deals with how space and time are perceived by different observers who are moving at constant speeds relative to each other, *without considering gravity*.\n\n**The Two Main Ideas of Special Relativity:**\n\n1.  **The Principle of Relativity:** The laws of physics are the same for everyone moving at a constant speed in a straight line.\n    *   **Simple Analogy:** Imagine you\'re on a train moving smoothly and steadily. If you close your eyes
# ...

# %%
msg=[("system, You are a helpful assistant that translates English to tamil."),
     ("user, Translate the following English text to Tamil: 'Hello, how are you?'")]
response = llm.invoke(msg)
print(response)
# Out:
# content='வணக்கம், எப்படி இருக்கிறீர்கள்?' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b2fa8-a7a1-7792-8f44-cc8966acfce5-0' usage_metadata={'input_tokens': 32, 'output_tokens': 148, 'total_tokens': 180, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 140}}

# %%
msg=""" What is 5+5? give me the answer directly."""
response = llm.invoke(msg)
print(response)
# Out:
# content='10' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b2fa8-aede-70d1-a8f2-b90b6da11159-0' usage_metadata={'input_tokens': 14, 'output_tokens': 47, 'total_tokens': 61, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 45}}

# %%
msg="""[a car has 4 wheels and an engine. A bike has 2 wheels and no engine.what is the number of wheels in a car and a bike together?]"""
response = llm.invoke(msg)
print(response)
# Out:
# content='A car has 4 wheels.\nA bike has 2 wheels.\n\nTogether, a car and a bike have 4 + 2 = **6 wheels**.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b2fa8-b458-77c1-90c8-4dadeb34994e-0' usage_metadata={'input_tokens': 36, 'output_tokens': 179, 'total_tokens': 215, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 145}}

# %%
msg="""act as a teacher teach me in a simple way .be helpful"""
response=llm.invoke(msg)
print(response)
# Out:
# content='Hello there! Wonderful to have you here.\n\nConsider me your guide on this learning journey. My goal is to make things clear, understandable, and even a little fun. No complicated jargon, no intimidating lectures. Just simple explanations, step by step.\n\nAnd remember, there are no "silly" questions in my classroom. If something isn\'t clear, or if you\'re curious about something, please, just ask! Your understanding is what matters most.\n\nNow, every good lesson starts with knowing what *you* want to learn!\n\n*   Is there a specific topic that\'s been on your mind?\n*   Something you\'re curious about?\n*   A skill you want to develop?\n*   Or maybe you just want to pick something completely new?\n\nDon\'t feel like you need a perfect answer right away. If you\'re not sure, just say "Surprise me!" and I can suggest a starting point.\n\nOnce you tell me, here\'s how we\'ll proceed:\n1.  **Break it Down:** We\'ll take the topic and chop it into small, easy-to-digest pieces
# ...

# %%
msg="""analyze the sentiment of the following text: 'I am extremely happy with the service I received today!'"""
response=llm.invoke(msg)
print(response)
# Out:
# content='The sentiment of the text is **highly positive**.\n\nThis is indicated by the strong positive emotional language used, specifically the phrase "extremely happy." The word "extremely" amplifies the positive feeling, suggesting a very high level of satisfaction. The exclamation mark further emphasizes this strong emotion.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b2fa8-deb7-78e0-af7b-b685dfd20fe6-0' usage_metadata={'input_tokens': 21, 'output_tokens': 556, 'total_tokens': 577, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 499}}
